# %%
import pickle
import matplotlib.pyplot as plt
from sklearn.linear_model import GammaRegressor

# %%
dat=pickle.load(open('/home/maria/Documents/HarvardData/processed_sessions_v3/Bo220226/session_responses.p','rb'))

# %%
dat.shape
# Out:
# (1250, 64)

# %%
gamma=GammaRegressor()

from sklearn.linear_model import Ridge

gamma.fit(clip,dat.T[0,:])

ridge=Ridge()

ridge.fit(clip,dat.T[0,:])

pred_ridge=ridge.predict(clip)

pred=gamma.predict(clip)

# %%
plt.plot(dat.T[0,:],pred,'o')
plt.show()
plt.plot(dat.T[0,:])
plt.plot(pred)
plt.show()

# %%
plt.plot(dat.T[0,:],pred_ridge,'o')
plt.show()
plt.plot(dat.T[0,:])
plt.plot(pred_ridge)
plt.show()

# %%
clip=pickle.load(open('/home/maria/Documents/HarvardData/processed_sessions_v3/Bo220226/clip_features.p','rb'))

# %%
clip.shape
# Out:
# (1250, 512)

# %%
from sklearn.linear_model import GammaRegressor

# %%
dat=pickle.load(open('/home/maria/Documents/HarvardData/processed_sessions_v3/Bo220226/session_responses.p','rb'))

# %%
dat
# Out:
# array([[ 39.70588303,  29.41176605,  17.64705849, ...,  14.70588207,
#          30.88235283,  33.8235321 ],
#        [ 42.64705658,  75.        ,  16.17647171, ..., 104.41176605,
#          64.70587921,  29.41176414],
#        [ 69.60784149,  63.72549057,  18.62745094, ...,  76.47058868,
#          50.        ,  40.19607925],
#        ...,
#        [ 35.29411697,  38.23529434,  21.5686264 , ...,  35.29411697,
#          76.47058868,  27.45098114],
#        [ 30.3921566 ,  45.09803772,  13.72549057, ...,  36.27450943,
#          41.17647171,  33.33333206],
#        [ 52.94117737,  32.35293961,   8.82352924, ...,  50.        ,
#          41.17647171,  23.52941132]])

# %%
dat.shape

plt.plot(dat[:,0])

# %%
plt.hist(dat[:,4])
# Out:
# (array([  5.,  39., 234., 463., 276., 148.,  50.,  28.,   6.,   1.]),
#  array([ 5.88235283, 13.23529415, 20.58823547, 27.9411768 , 35.29411812,
#         42.64705944, 50.00000076, 57.35294209, 64.70588341, 72.05882473,
#         79.41176605]),
#  <BarContainer object of 10 artists>)

# %%
ims=pickle.load(open('/home/maria/Documents/HarvardData/processed_sessions_v3/Bo220226/session_images.p','rb'))
len(ims)
# Out:
# 1250
